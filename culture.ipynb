# %%
import requests
import bs4
import os
import time
import random
import urllib.request as ur
# pc端的user-agent
user_agent_pc = [
    # 谷歌
    'Mozilla/5.0.html (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.html.2171.71 Safari/537.36',
    'Mozilla/5.0.html (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.html.1271.64 Safari/537.11',
    'Mozilla/5.0.html (Windows; U; Windows NT 6.1; en-US) AppleWebKit/534.16 (KHTML, like Gecko) Chrome/10.0.html.648.133 Safari/534.16',
    # 火狐
    'Mozilla/5.0.html (Windows NT 6.1; WOW64; rv:34.0.html) Gecko/20100101 Firefox/34.0.html',
    'Mozilla/5.0.html (X11; U; Linux x86_64; zh-CN; rv:1.9.2.10) Gecko/20100922 Ubuntu/10.10 (maverick) Firefox/3.6.10',
    # opera
    'Mozilla/5.0.html (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.html.2171.95 Safari/537.36 OPR/26.0.html.1656.60',
    # qq浏览器
    'Mozilla/5.0.html (compatible; MSIE 9.0.html; Windows NT 6.1; WOW64; Trident/5.0.html; SLCC2; .NET CLR 2.0.html.50727; .NET CLR 3.5.30729; .NET CLR 3.0.html.30729; Media Center PC 6.0.html; .NET4.0C; .NET4.0E; QQBrowser/7.0.html.3698.400)',
    # 搜狗浏览器
    'Mozilla/5.0.html (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.html.963.84 Safari/535.11 SE 2.X MetaSr 1.0.html',
    # 360浏览器
    'Mozilla/5.0.html (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/30.0.html.1599.101 Safari/537.36',
    'Mozilla/5.0.html (Windows NT 6.1; WOW64; Trident/7.0.html; rv:11.0.html) like Gecko',
    # uc浏览器
    'Mozilla/5.0.html (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/38.0.html.2125.122 UBrowser/4.0.html.3214.0.html Safari/537.36',
]
# 移动端的user-agent
user_agent_phone = [
    # IPhone
    'Mozilla/5.0.html (iPhone; U; CPU iPhone OS 4_3_3 like Mac OS X; en-us) AppleWebKit/533.17.9 (KHTML, like Gecko) Version/5.0.html.2 Mobile/8J2 Safari/6533.18.5',
    # IPAD
    'Mozilla/5.0.html (iPad; U; CPU OS 4_2_1 like Mac OS X; zh-cn) AppleWebKit/533.17.9 (KHTML, like Gecko) Version/5.0.html.2 Mobile/8C148 Safari/6533.18.5',
    'Mozilla/5.0.html (iPad; U; CPU OS 4_3_3 like Mac OS X; en-us) AppleWebKit/533.17.9 (KHTML, like Gecko) Version/5.0.html.2 Mobile/8J2 Safari/6533.18.5',
    # Android
    'Mozilla/5.0.html (Linux; U; Android 2.2.1; zh-cn; HTC_Wildfire_A3333 Build/FRG83D) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0.html Mobile Safari/533.1',
    'Mozilla/5.0.html (Linux; U; Android 2.3.7; en-us; Nexus One Build/FRF91) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0.html Mobile Safari/533.1',
    # QQ浏览器 Android版本
    'MQQBrowser/26 Mozilla/5.0.html (Linux; U; Android 2.3.7; zh-cn; MB200 Build/GRJ22; CyanogenMod-7) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0.html Mobile Safari/533.1',
    # Android Opera Mobile
    'Opera/9.80 (Android 2.3.4; Linux; Opera Mobi/build-1107180945; U; en-GB) Presto/2.8.149 Version/11.10',
    # Android Pad Moto Xoom
    'Mozilla/5.0.html (Linux; U; Android 3.0.html; en-us; Xoom Build/HRI39) AppleWebKit/534.13 (KHTML, like Gecko) Version/4.0.html Safari/534.13',
]

def get_user_agent_pc():
    return random.choice(user_agent_pc)

def get_user_agent_phone():
    return random.choice(user_agent_phone)


def fetchUrl(url):
    headers = {
        'user-agent': get_user_agent_pc()
    }
    r = requests.get(url,headers=headers)
#     print(r)
#     r.raise_for_status()
#     r.encoding = r.apparent_encoding
    r.encoding = "gb2312"
    
    return r.text

def getPageList():

    i=1
    web = 'http://search.people.com.cn'  #  目标网址
    str1 = '/cnpeople/search.do?pageNum='
    str2 = str(i)
    str3 = '&keyword=%B9%A4%D2%D5&siteName=news&facetFlag=false&nodeType=belongsId&nodeId='

    url = web + str1 + str2 + str3

    print(url)
    html = fetchUrl(url)
    bsobj = bs4.BeautifulSoup(html,'html.parser')
#     print(bsobj.text)
#         if bsobj.test != '':
    pageList = bsobj.find('div', attrs = {'class': 'fr w800'}).find_all('a')
#             pageList  = pageList1.find_all('ul')
#             pageList = bsobj.find('ul')
#             pageList = pageList1.to_dict()
    print(type(pageList))
    linkList = []
    for page in pageList:
#         print(page)
        link = page.get("href")
        if link[0] == 'h':
            linkList.append(link)
#     print('####################')
    linkList = list(set(linkList))
    print(linkList) 
    return linkList

# def getTitleList(pageUrl):
    
#     html = fetchUrl(pageUrl)
#     bsobj = bs4.BeautifulSoup(html,'html.parser')
#     titleList1 = bsobj.find('div', attrs = {'class': 'ywjy_content'})
#     titleList  = titleList1.find_all('a')
#     linkList = []
    
#     for title in titleList:
#         tempList = title.find_all('a')
#         for temp in tempList:
#             link = temp["href"]
#             if 'miit' in link:
#                 url = 'http://www.gov.cn/fuwu/bm/gyhxxhb/index.htm' + link
#                 linkList.append(url)
    
#     return linkList

def getContent(html):
    print(html)
    bsobj = bs4.BeautifulSoup(html,'html.parser')
    print(html)
    title = bsobj.h1.text + '\n' 
    print(title)
    
    pList = bsobj.find('div', attrs = {'id': 'rwb_zw'}).find_all('p')
    content = ''
    for p in pList:
        content += p.text + '\n'      
    print(content)
    
    resp = title + content
    return resp

def saveFile(content, path, filename):

    if not os.path.exists(path):
        os.makedirs(path)
    with open(path + filename, 'w', encoding='utf-8') as f:
        f.write(content)
        
def download_rmrb(destdir):

    pageList = getPageList()
    i=1
    for page in pageList:
#         titleList = getTitleList(page)
#     for url in pageList:
        html = fetchUrl(page)
        content = getContent(html)            
        path = destdir + '/' 
        
        fileName =i + '.txt'
        i=i+1
        saveFile(content, path, fileName)
    
            
if __name__ == '__main__':

    destdir = "K:/download"
 
    download_rmrb(destdir)
    print("爬取完成：")
# Out:
# http://search.people.com.cn/cnpeople/search.do?pageNum=1&keyword=%B9%A4%D2%D5&siteName=news&facetFlag=false&nodeType=belongsId&nodeId=
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-9904a9c95919> in <module>
#     155     destdir = "K:/download"
#     156
# --> 157     download_rmrb(destdir)
#     158     print("爬取完成：")
#
# <ipython-input-29-9904a9c95919> in download_rmrb(destdir)
#     137 def download_rmrb(destdir):
#     138
# --> 139     pageList = getPageList()
#     140     i=1
#     141     for page in pageList:
#
# <ipython-input-29-9904a9c95919> in getPageList()
#      78 #     print(bsobj.text)
#      79 #         if bsobj.test != '':
# ---> 80     pageList = bsobj.find('div', attrs = {'class': 'fr w800'}).find_all('a')
#      81 #             pageList  = pageList1.find_all('ul')
#      82 #             pageList = bsobj.find('ul')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
from bs4 import BeautifulSoup
import requests

html = "http://culture.people.com.cn/n1/2020/1124/c1013-31942686.html"
main_resp = requests.get(html)
main_resp.encoding = "gb2312"

bsobj =BeautifulSoup(main_resp.text,'html.parser')

title = bsobj.h1.text + '\n' 

print(title)
# title = bsobj.get("h1") + '\n'
# Out:
# 推进社会主义文化强国建设（学习贯彻党的十九届五中全会精神）

# %%
import requests
import bs4
import os
import time
import random
import urllib.request as ur
# pc端的user-agent
user_agent_pc = [
    # 谷歌
    'Mozilla/5.0.html (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.html.2171.71 Safari/537.36',
    'Mozilla/5.0.html (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.html.1271.64 Safari/537.11',
    'Mozilla/5.0.html (Windows; U; Windows NT 6.1; en-US) AppleWebKit/534.16 (KHTML, like Gecko) Chrome/10.0.html.648.133 Safari/534.16',
    # 火狐
    'Mozilla/5.0.html (Windows NT 6.1; WOW64; rv:34.0.html) Gecko/20100101 Firefox/34.0.html',
    'Mozilla/5.0.html (X11; U; Linux x86_64; zh-CN; rv:1.9.2.10) Gecko/20100922 Ubuntu/10.10 (maverick) Firefox/3.6.10',
    # opera
    'Mozilla/5.0.html (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.html.2171.95 Safari/537.36 OPR/26.0.html.1656.60',
    # qq浏览器
    'Mozilla/5.0.html (compatible; MSIE 9.0.html; Windows NT 6.1; WOW64; Trident/5.0.html; SLCC2; .NET CLR 2.0.html.50727; .NET CLR 3.5.30729; .NET CLR 3.0.html.30729; Media Center PC 6.0.html; .NET4.0C; .NET4.0E; QQBrowser/7.0.html.3698.400)',
    # 搜狗浏览器
    'Mozilla/5.0.html (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.html.963.84 Safari/535.11 SE 2.X MetaSr 1.0.html',
    # 360浏览器
    'Mozilla/5.0.html (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/30.0.html.1599.101 Safari/537.36',
    'Mozilla/5.0.html (Windows NT 6.1; WOW64; Trident/7.0.html; rv:11.0.html) like Gecko',
    # uc浏览器
    'Mozilla/5.0.html (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/38.0.html.2125.122 UBrowser/4.0.html.3214.0.html Safari/537.36',
]
# 移动端的user-agent
user_agent_phone = [
    # IPhone
    'Mozilla/5.0.html (iPhone; U; CPU iPhone OS 4_3_3 like Mac OS X; en-us) AppleWebKit/533.17.9 (KHTML, like Gecko) Version/5.0.html.2 Mobile/8J2 Safari/6533.18.5',
    # IPAD
    'Mozilla/5.0.html (iPad; U; CPU OS 4_2_1 like Mac OS X; zh-cn) AppleWebKit/533.17.9 (KHTML, like Gecko) Version/5.0.html.2 Mobile/8C148 Safari/6533.18.5',
    'Mozilla/5.0.html (iPad; U; CPU OS 4_3_3 like Mac OS X; en-us) AppleWebKit/533.17.9 (KHTML, like Gecko) Version/5.0.html.2 Mobile/8J2 Safari/6533.18.5',
    # Android
    'Mozilla/5.0.html (Linux; U; Android 2.2.1; zh-cn; HTC_Wildfire_A3333 Build/FRG83D) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0.html Mobile Safari/533.1',
    'Mozilla/5.0.html (Linux; U; Android 2.3.7; en-us; Nexus One Build/FRF91) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0.html Mobile Safari/533.1',
    # QQ浏览器 Android版本
    'MQQBrowser/26 Mozilla/5.0.html (Linux; U; Android 2.3.7; zh-cn; MB200 Build/GRJ22; CyanogenMod-7) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0.html Mobile Safari/533.1',
    # Android Opera Mobile
    'Opera/9.80 (Android 2.3.4; Linux; Opera Mobi/build-1107180945; U; en-GB) Presto/2.8.149 Version/11.10',
    # Android Pad Moto Xoom
    'Mozilla/5.0.html (Linux; U; Android 3.0.html; en-us; Xoom Build/HRI39) AppleWebKit/534.13 (KHTML, like Gecko) Version/4.0.html Safari/534.13',
]

def get_user_agent_pc():
    return random.choice(user_agent_pc)

def get_user_agent_phone():
    return random.choice(user_agent_phone)



def fetchUrl(url):
    headers = {
        'user-agent': get_user_agent_pc()
    }
    r = requests.get(url,headers=headers)
    r.encoding = "gb2312" 
    return r.text

def getPageList():

    web = 'http://culture.people.com.cn/GB/430416/index.html'  #  目标网址
    web1 = 'http://culture.people.com.cn'
    html = fetchUrl(web)
    bsobj = bs4.BeautifulSoup(html,'html.parser')
    pageList = bsobj.find('div', attrs = {'class': 'ej_list_box clear'}).find_all('a')
    linkList = []
    for page in pageList:

        try:
            str1 = page['href']
        except:
            str1='111'
        if str1[0] == '/' or str1[0] == 'h':
            if str1[0] == '/' :
                link = web1 + str1
            else :
                link == str1
            linkList.append(link)
    return linkList

def getContent(html):
    bsobj = bs4.BeautifulSoup(html,'html.parser')
    title = bsobj.h1.text + '\n'    
    pList = bsobj.find('div', attrs = {'id': 'rwb_zw'}).find_all('p')
    content = ''
    for p in pList:
        content += p.text + '\n'      
    resp = title + content
    return resp

def saveFile(content, path, filename):

    if not os.path.exists(path):
        os.makedirs(path)
    with open(path + filename, 'w', encoding='utf-8') as f:
        f.write(content)
        
def download_rmrb(destdir):

    pageList = getPageList()
    i=233
    for page in pageList:
#         titleList = getTitleList(page)
#     for url in pageList:
        html = fetchUrl(page)
        content = getContent(html)            
        path = destdir + '/' 
        
        fileName =str(i) + '人民娱评.txt'
        i=i+1
        saveFile(content, path, fileName)
    
            
if __name__ == '__main__':

    destdir = "K:/download"
 
    download_rmrb(destdir)
    print("爬取完成！")
# Out:
# 爬取完成！

# %%
import requests
import bs4
import os
import time
import random
import urllib.request as ur
# pc端的user-agent
user_agent_pc = [
    # 谷歌
    'Mozilla/5.0.html (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.html.2171.71 Safari/537.36',
    'Mozilla/5.0.html (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.html.1271.64 Safari/537.11',
    'Mozilla/5.0.html (Windows; U; Windows NT 6.1; en-US) AppleWebKit/534.16 (KHTML, like Gecko) Chrome/10.0.html.648.133 Safari/534.16',
    # 火狐
    'Mozilla/5.0.html (Windows NT 6.1; WOW64; rv:34.0.html) Gecko/20100101 Firefox/34.0.html',
    'Mozilla/5.0.html (X11; U; Linux x86_64; zh-CN; rv:1.9.2.10) Gecko/20100922 Ubuntu/10.10 (maverick) Firefox/3.6.10',
    # opera
    'Mozilla/5.0.html (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.html.2171.95 Safari/537.36 OPR/26.0.html.1656.60',
    # qq浏览器
    'Mozilla/5.0.html (compatible; MSIE 9.0.html; Windows NT 6.1; WOW64; Trident/5.0.html; SLCC2; .NET CLR 2.0.html.50727; .NET CLR 3.5.30729; .NET CLR 3.0.html.30729; Media Center PC 6.0.html; .NET4.0C; .NET4.0E; QQBrowser/7.0.html.3698.400)',
    # 搜狗浏览器
    'Mozilla/5.0.html (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.html.963.84 Safari/535.11 SE 2.X MetaSr 1.0.html',
    # 360浏览器
    'Mozilla/5.0.html (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/30.0.html.1599.101 Safari/537.36',
    'Mozilla/5.0.html (Windows NT 6.1; WOW64; Trident/7.0.html; rv:11.0.html) like Gecko',
    # uc浏览器
    'Mozilla/5.0.html (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/38.0.html.2125.122 UBrowser/4.0.html.3214.0.html Safari/537.36',
]
# 移动端的user-agent
user_agent_phone = [
    # IPhone
    'Mozilla/5.0.html (iPhone; U; CPU iPhone OS 4_3_3 like Mac OS X; en-us) AppleWebKit/533.17.9 (KHTML, like Gecko) Version/5.0.html.2 Mobile/8J2 Safari/6533.18.5',
    # IPAD
    'Mozilla/5.0.html (iPad; U; CPU OS 4_2_1 like Mac OS X; zh-cn) AppleWebKit/533.17.9 (KHTML, like Gecko) Version/5.0.html.2 Mobile/8C148 Safari/6533.18.5',
    'Mozilla/5.0.html (iPad; U; CPU OS 4_3_3 like Mac OS X; en-us) AppleWebKit/533.17.9 (KHTML, like Gecko) Version/5.0.html.2 Mobile/8J2 Safari/6533.18.5',
    # Android
    'Mozilla/5.0.html (Linux; U; Android 2.2.1; zh-cn; HTC_Wildfire_A3333 Build/FRG83D) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0.html Mobile Safari/533.1',
    'Mozilla/5.0.html (Linux; U; Android 2.3.7; en-us; Nexus One Build/FRF91) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0.html Mobile Safari/533.1',
    # QQ浏览器 Android版本
    'MQQBrowser/26 Mozilla/5.0.html (Linux; U; Android 2.3.7; zh-cn; MB200 Build/GRJ22; CyanogenMod-7) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0.html Mobile Safari/533.1',
    # Android Opera Mobile
    'Opera/9.80 (Android 2.3.4; Linux; Opera Mobi/build-1107180945; U; en-GB) Presto/2.8.149 Version/11.10',
    # Android Pad Moto Xoom
    'Mozilla/5.0.html (Linux; U; Android 3.0.html; en-us; Xoom Build/HRI39) AppleWebKit/534.13 (KHTML, like Gecko) Version/4.0.html Safari/534.13',
]

def get_user_agent_pc():
    return random.choice(user_agent_pc)

def get_user_agent_phone():
    return random.choice(user_agent_phone)



def fetchUrl(url):
    headers = {
        'user-agent': get_user_agent_pc()
    }
    r = requests.get(url,headers=headers)
    r.encoding = "gb2312" 
    return r.text

def getPageList():

    web = 'http://culture.people.com.cn/GB/430418/index.html'  #  目标网址
    web1 = 'http://culture.people.com.cn'
    html = fetchUrl(web)
    bsobj = bs4.BeautifulSoup(html,'html.parser')
    pageList = bsobj.find('ul', attrs = {'class': 'clearfix'}).find_all('a')
    linkList = []
    for page in pageList:

        try:
            str1 = page['href']
        except:
            str1='111'
        if str1[0] == '/' or str1[0] == 'h':
            if str1[0] == '/' :
                link = web1 + str1
            else :
                link = str1
            linkList.append(link)
    return linkList

def getContent(html):
    bsobj = bs4.BeautifulSoup(html,'html.parser')
    title = bsobj.h1.text + '\n'    
    pList = bsobj.find('div', attrs = {'id': 'rwb_zw'}).find_all('p')
    content = ''
    for p in pList:
        content += p.text + '\n'      
    resp = title + content
    return resp

def saveFile(content, path, filename):

    if not os.path.exists(path):
        os.makedirs(path)
    with open(path + filename, 'w', encoding='utf-8') as f:
        f.write(content)
        
def download_rmrb(destdir):

    pageList = getPageList()
    i=394
    for page in pageList:
#         titleList = getTitleList(page)
#     for url in pageList:
        html = fetchUrl(page)
        content = getContent(html)            
        path = destdir + '/' 
        
        fileName =str(i) + '文艺开讲.txt'
        i=i+1
        saveFile(content, path, fileName)
    
            
if __name__ == '__main__':

    destdir = "K:/download"
 
    download_rmrb(destdir)
    print("爬取完成！")
# Out:
# 爬取完成！
